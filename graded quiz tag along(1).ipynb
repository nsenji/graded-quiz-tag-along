# %%
import pandas as pd

# %%
data = pd.read_csv("FoodBalanceSheets_E_Africa_NOFLAG.csv",encoding="latin-1")

# %%
data.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %% [markdown]
# # What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?

# %%
data.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %% [markdown]
# # Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?

# %%
data.groupby(['Area'])['Y2017'].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
data.isnull()
# Out:
#        Area Code   Area  Item Code   Item  Element Code  Element   Unit  \
# 0          False  False      False  False         False    False  False
# 1          False  False      False  False         False    False  False
# 2          False  False      False  False         False    False  False
# 3          False  False      False  False         False    False  False
# 4          False  False      False  False         False    False  False
# ...          ...    ...        ...    ...           ...      ...    ...
# 60938      False  False      False  False         False    False  False
# 60939      False  False      False  False         False    False  False
# 60940      False  False      False  False         False    False  False
# 60941      False  False      False  False         False    False  False
# 60942      False  False      False  False         False    False  False
#
#        Y2014  Y2015  Y2016  Y2017  Y2018
# 0      False  False  False  False  False
# ...

# %% [markdown]
# # What is the total number and percentage of missing data in 2014 to 3 decimal places?

# %%
missing_values=data.isnull().sum()
print(missing_values)

total= data['Y2014'].count()
# percentage = ((missing_values['Y2014'])/total)*100
num = missing_values['Y2014']
percentage = (num/total)*100
print(num)
print(percentage)
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64
# 1589
# 2.6771573946153584

# %% [markdown]
# # Answer the following questions based on the African food production dataset provided by the FAO website already provided

# %%
grouped = data.groupby(['Item'])
result = grouped[['Y2015','Y2018']].sum()
print(result)
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %% [markdown]
# # Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?

# %%
grouped = data.groupby(['Element'])
result = grouped['Y2014'].sum()
print(result)
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %% [markdown]
# # Which year had the least correlation with ‘Element Code’?

# %%
correlation = data['Y2015'].corr(data['Element Code'])
correlation2 = data['Y2014'].corr(data['Element Code'])
correlation3 = data['Y2017'].corr(data['Element Code'])
correlation4 = data['Y2016'].corr(data['Element Code'])

print(correlation)
print(correlation2)
print(correlation3)
print(correlation4)
# Out:
# 0.022414737959091692
# 0.022984691712605584
# 0.022711449450930787
# 0.021910115995853553

# %% [markdown]
# # How would you check for the number of rows and columns in a pandas DataFrame named df?

# %%
data.shape
# Out:
# (60943, 12)

# %% [markdown]
# # What is the total number of unique countries in the dataset?

# %%
data.nunique()
# Out:
# Area Code         49
# Area              49
# Item Code        122
# Item             119
# Element Code      18
# Element           18
# Unit               5
# Y2014           4493
# Y2015           4520
# Y2016           4520
# Y2017           4537
# Y2018           4591
# dtype: int64

# %% [markdown]
# # Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?

# %%
grouped = data.groupby(['Element'])
result = grouped['Y2017'].sum()
print(result)
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
group = data.groupby(['Element','Area'])['Y2015'].sum()
print(pd.DataFrame(group))
# Out:
#                                                    Y2015
# Element                  Area
# Domestic supply quantity Algeria                85972.86
#                          Angola                 55482.91
#                          Benin                  27661.67
#                          Botswana                2916.14
#                          Burkina Faso           23658.17
# ...                                                  ...
# Tourist consumption      Cabo Verde                 5.00
#                          Egypt                    286.00
#                          Kenya                     17.00
#                          Mauritius                 29.00
#                          Sao Tome and Principe     12.00
#
# [803 rows x 1 columns]

# %% [markdown]
# # What is the total Protein supply quantity in Madagascar in 2015?

# %%
group = data.groupby(['Element','Area'])['Y2015'].sum()

row = group.loc['Protein supply quantity (g/capita/day)']
print(row)
# Out:
# Area
# Algeria                        377.37
# Angola                         214.15
# Benin                          271.97
# Botswana                       278.52
# Burkina Faso                   317.99
# Cabo Verde                     278.41
# Cameroon                       291.53
# Central African Republic       173.70
# Chad                           252.28
# Congo                          227.08
# Côte d'Ivoire                  232.59
# Djibouti                       269.59
# Egypt                          394.87
# Eswatini                       237.71
# Ethiopia                       259.82
# Gabon                          345.41
# Gambia                         257.67
# Ghana                          241.71
# Guinea                         227.46
# Guinea-Bissau                  168.61
# Kenya                          251.73
# Lesotho                        254.50
# Liberia                        159.43
# Madagascar                     173.05
# ...
